# %%
import pandas as pd

# %%
df = pd.read_csv('../Resources/Data/user_scrape_data/WV/cleaned.csv')

# %%
df
# Out:
#                                       Utility  Contaminant_Factor    Zip  \
# 0    Appalachian Teen Challenge Female Center                  66  24701
# 1                              Athens Town Of                 664  24701
# 2                                Bluewell Psd                1559  24701
# 3          Green Valley Glenwood Psd Bulltail                2278  24701
# 4                  Pinnacle Water Association                  38  24701
# ..                                        ...                 ...    ...
# 338                Moorefield Municipal Water                1013  26755
# 339                      Wardensville Town Of                 343  26755
# 340                  Franklin Municipality Of                 237  26802
# 341             Pendleton Co. Psd(brandywine)                3183  26802
# 342             Pendleton County Psd Riverton                  97  26802
#
#      county_FIPS
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# ...
