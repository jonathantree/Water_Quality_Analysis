# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
EWG_Scrape_df = pd.read_csv('../Resources/Data/Raw_OR_EWG_Scrape_no_index.csv')

# %%
utils_zip_df = pd.read_csv('../Resources/Data/Clean_Utilities_zipcode.csv')

# %%
EWG_Scrape_df.columns
# Out:
# Index(['Utility', 'Contaminant', 'Utility Measuremnt', 'EWG HEALTH GUIDELINE',
#        'Legal Limit'],
#       dtype='object')

# %%
EWG_Scrape_df
# Out:
#                     Utility                           Contaminant  \
# 0         City of Pendleton                               Arsenic
# 1         City of Pendleton                 Chromium (hexavalent)
# 2         City of Pendleton              Haloacetic acids (HAA5)†
# 3         City of Pendleton              Haloacetic acids (HAA9)†
# 4         City of Pendleton                               Nitrate
# ...                     ...                                   ...
# 2999  Westridge Subdivision    Radium, combined (-226 &amp; -228)
# 3000  Westridge Subdivision  Dichloromethane (methylene chloride)
# 3001  Westridge Subdivision                              Fluoride
# 3002  Westridge Subdivision                             Manganese
# 3003  Westridge Subdivision                                  None
#
#      Utility Measuremnt EWG HEALTH GUIDELINE Legal Limit
# 0             0.750 ppb            0.004 ppb      10 ppb
# 1            0.0472 ppb             0.02 ppb         NaN
# ...

# %%
re.findallr'\d+'

# %%
box_office.str.find(r'\d+', '$', regex=True)

# %%
multi = EWG_Scrape_df.set_index(['Utility', 'Contaminant']).sort_index()

# %%
multi
# Out:
#                                                                           Utility Measuremnt  \
# Utility                                    Contaminant
# 1485 Limited Crystal Springs Water Company Barium                                  119.5 ppb
#                                            Nitrate                                0.0333 ppm
#                                            Nitrate and nitrite                    0.0500 ppm
#                                            None                                          NaN
# Adair Village Water System                 Barium                                   4.00 ppb
# ...                                                                                      ...
# Youngs River Lewis & Clark Water District  Nitrate                                 0.620 ppm
#                                            Nitrate and nitrite                     0.480 ppm
# ...

# %%
EWG_Scrape_df.set_index('Utility', inplace=True)
EWG_Scrape_df
# Out:
#                                                 Contaminant  \
# Utility
# City of Pendleton                                   Arsenic
# City of Pendleton                     Chromium (hexavalent)
# City of Pendleton                  Haloacetic acids (HAA5)†
# City of Pendleton                  Haloacetic acids (HAA9)†
# City of Pendleton                                   Nitrate
# ...                                                     ...
# Westridge Subdivision    Radium, combined (-226 &amp; -228)
# Westridge Subdivision  Dichloromethane (methylene chloride)
# Westridge Subdivision                              Fluoride
# Westridge Subdivision                             Manganese
# Westridge Subdivision                                  None
#
#                       Utility Measuremnt EWG HEALTH GUIDELINE Legal Limit
# Utility
# City of Pendleton              0.750 ppb            0.004 ppb      10 ppb
# City of Pendleton             0.0472 ppb             0.02 ppb         NaN
# ...

# %%
EWG_Scrape_df.reset_index(inplace=True)

# %%
EWG_Scrape_df.columns
# Out:
# Index(['Utility', 'Contaminant', 'Utility Measuremnt', 'EWG HEALTH GUIDELINE',
#        'Legal Limit'],
#       dtype='object')

# %%
EWG_Scrape_df
# Out:
#                     Utility                           Contaminant  \
# 0         City of Pendleton                               Arsenic
# 1         City of Pendleton                 Chromium (hexavalent)
# 2         City of Pendleton              Haloacetic acids (HAA5)†
# 3         City of Pendleton              Haloacetic acids (HAA9)†
# 4         City of Pendleton                               Nitrate
# ...                     ...                                   ...
# 2999  Westridge Subdivision    Radium, combined (-226 &amp; -228)
# 3000  Westridge Subdivision  Dichloromethane (methylene chloride)
# 3001  Westridge Subdivision                              Fluoride
# 3002  Westridge Subdivision                             Manganese
# 3003  Westridge Subdivision                                  None
#
#      Utility Measuremnt EWG HEALTH GUIDELINE Legal Limit
# 0             0.750 ppb            0.004 ppb      10 ppb
# 1            0.0472 ppb             0.02 ppb         NaN
# ...

# %%
df2 = EWG_Scrape_df[EWG_Scrape_df.Utility == 'City of Pendleton']

# %%
df2
# Out:
#               Utility                     Contaminant Utility Measuremnt  \
# 0   City of Pendleton                         Arsenic          0.750 ppb
# 1   City of Pendleton           Chromium (hexavalent)         0.0472 ppb
# 2   City of Pendleton        Haloacetic acids (HAA5)†           15.3 ppb
# 3   City of Pendleton        Haloacetic acids (HAA9)†           16.2 ppb
# 4   City of Pendleton                         Nitrate           1.40 ppm
# 5   City of Pendleton  Total trihalomethanes (TTHMs)†           25.5 ppb
# 6   City of Pendleton                         Uranium         0.89 pCi/L
# 7   City of Pendleton                        Chlorate          125.9 ppb
# 8   City of Pendleton                Chromium (total)         0.0338 ppb
# 9   City of Pendleton                       Manganese           3.99 ppb
# 10  City of Pendleton                      Molybdenum          0.381 ppb
# 11  City of Pendleton                       Strontium         0.0703 ppb
# ...

# %%
df2.columns
# Out:
# Index(['Utility', 'Contaminant', 'Utility Measuremnt', 'EWG HEALTH GUIDELINE',
#        'Legal Limit'],
#       dtype='object')

# %%
util_meas[0].split()
# Out:
# ['0.750', 'ppb']

# %%
#df[['Street', 'City', 'State']] = df['Address'].str.split(',', expand=True)
df2[['Utility Measurement', 'Units']] = df2['Utility Measuremnt'].str.split(expand=True)
df2['EWG HEALTH GUIDELINE', 'Units'] = df2['EWG HEALTH GUIDELINE'].str.split(expand=True)
df2['Legal Limit', 'Units'] = df2['Legal Limit'].str.split(expand=True)
# Out:
# C:\Users\jonat\AppData\Local\Temp\ipykernel_13880\730458815.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[['Utility Measurement', 'Units']] = df2['Utility Measuremnt'].str.split(expand=True)
# C:\Users\jonat\AppData\Local\Temp\ipykernel_13880\730458815.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[['Utility Measurement', 'Units']] = df2['Utility Measuremnt'].str.split(expand=True)
# ---------------------------------------------------------------------------
# ...

# %%
df2
# Out:
#               Utility                     Contaminant Utility Measuremnt  \
# 0   City of Pendleton                         Arsenic          0.750 ppb
# 1   City of Pendleton           Chromium (hexavalent)         0.0472 ppb
# 2   City of Pendleton        Haloacetic acids (HAA5)†           15.3 ppb
# 3   City of Pendleton        Haloacetic acids (HAA9)†           16.2 ppb
# 4   City of Pendleton                         Nitrate           1.40 ppm
# 5   City of Pendleton  Total trihalomethanes (TTHMs)†           25.5 ppb
# 6   City of Pendleton                         Uranium         0.89 pCi/L
# 7   City of Pendleton                        Chlorate          125.9 ppb
# 8   City of Pendleton                Chromium (total)         0.0338 ppb
# 9   City of Pendleton                       Manganese           3.99 ppb
# 10  City of Pendleton                      Molybdenum          0.381 ppb
# 11  City of Pendleton                       Strontium         0.0703 ppb
# ...

# %%
df2['EWG HEALTH GUIDELINE'] = df2['EWG HEALTH GUIDELINE'][0]
df2['Legal Limit'] = df2['Legal Limit'][0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13880\3388853603.py in <cell line: 1>()
# ----> 1 df2['EWG HEALTH GUIDELINE'] = df2['EWG HEALTH GUIDELINE'][0]
#       2 df2['Legal Limit'] = df2['Legal Limit'][0]
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3653         else:
#    3654             # set column
# -> 3655             self._set_item(key, value)
#    3656
#    3657     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3830         ensure homogeneity.
#    3831         """
# -> 3832         value = self._sanitize_column(value)
#    3833
#    3834         if (
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, value)
#    4533
# ...

# %%
df = df2.copy()
df.columns
# Out:
# Index(['Utility', 'Contaminant', 'Utility Measuremnt', 'EWG HEALTH GUIDELINE',
#        'Legal Limit'],
#       dtype='object')

# %%
#df['Utility Measuremnt'] = df['Utility Measuremnt'].str.extract('(\d+\.\d+)')
df['Utility Measuremnt'] = df['Utility Measuremnt'].str.extract('(\d*\.\d+|\d+)')
df['EWG HEALTH GUIDELINE'] = df['EWG HEALTH GUIDELINE'].str.extract('(\d*\.\,\d+|\d+)')
df['Legal Limit'] = df['Legal Limit'].str.extract('(\d*\.\d+|\d+)')

# %%
df
# Out:
#               Utility                     Contaminant Utility Measuremnt  \
# 0   City of Pendleton                         Arsenic              0.750
# 1   City of Pendleton           Chromium (hexavalent)             0.0472
# 2   City of Pendleton        Haloacetic acids (HAA5)†               15.3
# 3   City of Pendleton        Haloacetic acids (HAA9)†               16.2
# 4   City of Pendleton                         Nitrate               1.40
# 5   City of Pendleton  Total trihalomethanes (TTHMs)†               25.5
# 6   City of Pendleton                         Uranium               0.89
# 7   City of Pendleton                        Chlorate              125.9
# 8   City of Pendleton                Chromium (total)             0.0338
# 9   City of Pendleton                       Manganese               3.99
# 10  City of Pendleton                      Molybdenum              0.381
# 11  City of Pendleton                       Strontium             0.0703
# ...

# %%
pd.pivot_table(df, index='Utility', columns='Contaminant')
# Out:
# C:\Users\jonat\AppData\Local\Temp\ipykernel_13880\875733202.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   pd.pivot_table(df, index='Utility', columns=  'Contaminant')
# Empty DataFrame
# Columns: []
# Index: [City of Pendleton]

# %%
df.pivot(columns='Contaminant', values=['Utility Measuremnt', 'EWG HEALTH GUIDELINE','Legal Limit'])
# Out:
#             Utility Measuremnt                                   \
# Contaminant            Arsenic   Chlorate Chromium (hexavalent)
# 0                    0.750 ppb        NaN                   NaN
# 1                          NaN        NaN            0.0472 ppb
# 2                          NaN        NaN                   NaN
# 3                          NaN        NaN                   NaN
# 4                          NaN        NaN                   NaN
# 5                          NaN        NaN                   NaN
# 6                          NaN        NaN                   NaN
# 7                          NaN  125.9 ppb                   NaN
# 8                          NaN        NaN                   NaN
# 9                          NaN        NaN                   NaN
# 10                         NaN        NaN                   NaN
# 11                         NaN        NaN                   NaN
# 12                         NaN        NaN                   NaN
# ...

# %%
utils_zip_df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
utils_zip_df
# Out:
#                                 Utility name                  City  \
# 0                          City of Pendleton         Pendleton, OR
# 1                          City of Hermiston         Hermiston, OR
# 2                  Milton-freewater, City Of  Milton-freewater, OR
# 3                          Umatilla, City of          Umatilla, OR
# 4                         Stanfield, City of         Stanfield, OR
# ..                                       ...                   ...
# 413   Quail Valley Park Improvement District            Prineville
# 414                         Shoun Crossroads            Prineville
# 415  Sunset Hills Domestic Water Association            Prineville
# 416                     Terrace Mobile Plaza            Prineville
# 417                    Westridge Subdivision            Prineville
#
#                 People served    Zip
# 0    Population served:17,310  97810
# 1    Population served:18,200  97810
# 2     Population served:7,070  97810
# ...

# %%
EWG_Scrape_df.dtypes
# Out:
# Utility                 object
# Contaminant             object
# Utility Measuremnt      object
# EWG HEALTH GUIDELINE    object
# Legal Limit             object
# dtype: object

# %%
EWG_pivot_df['idx'] = EWG_Scrape_df.groupby('Utility')

# %%
EWG_pivot_df
# Out:
# 0       0
# 1       1
# 2       2
# 3       3
# 4       4
#        ..
# 2999    0
# 3000    1
# 3001    2
# 3002    3
# 3003    4
# Length: 3004, dtype: int64

# %%
df = pd.DataFrame(EWG_pivot_df)

# %%
df
# Out:
#                                               0  \
# 0    1485 Limited Crystal Springs Water Company
# 1                    Adair Village Water System
# 2                               Adrian, City of
# 3                            Agate Water System
# 4             Alder Creek Barlow Water District
# ..                                          ...
# 400                       Wood Village, City of
# 401                            Yachats, City of
# 402                           Yoncalla, City of
# 403                                  Young Life
# 404   Youngs River Lewis & Clark Water District
#
#                                                      1
# 0                                             Utili...
# 1                             Utility              ...
# 2                Utility       Contaminant Utility ...
# 3                     Utility          Contaminant ...
# 4                                   Utility        ...
# ...

# %%
multi.pivot(columns=['Utility Measuremnt', 'EWG HEALTH GUIDELINE','Legal Limit'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4464\3775401108.py in <cell line: 1>()
# ----> 1 multi.pivot(columns=['Utility Measuremnt', 'EWG HEALTH GUIDELINE','Legal Limit'])
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\frame.py in pivot(self, index, columns, values)
#    7874         from pandas.core.reshape.pivot import pivot
#    7875
# -> 7876         return pivot(self, index=index, columns=columns, values=values)
#    7877
#    7878     _shared_docs[
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\reshape\pivot.py in pivot(data, index, columns, values)
#     518         else:
#     519             indexed = data._constructor_sliced(data[values]._values, index=multiindex)
# --> 520     return indexed.unstack(columns_listlike)
#     521
#     522
#
# ...
