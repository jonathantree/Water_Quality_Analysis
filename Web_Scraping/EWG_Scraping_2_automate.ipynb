# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup as soup
import pandas as pd
import requests

# %%
driver = webdriver.Chrome()
driver.get("https://www.ewg.org/tapwater/")

# %%
element = driver.find_element(By.XPATH,'/html/body/main/section[1]/form/input[1]')

# %%
element.send_keys('97045')

# %%
button = driver.find_element(By.XPATH,'/html/body/main/section[1]/form/input[3]').click()

# %%
zip_url = driver.current_url
zip_url
# Out:
# 'https://www.ewg.org/tapwater/search-results.php?zip5=97045&searchtype=zip'

# %%
url = requests.get(zip_url)
table = pd.read_html(url.text)

# %%
table
# Out:
# [                              Utility name              City  \
#  0  North Clackamas County Water Commission   Oregon City, OR
#  1                   South Fork Water Board   Oregon City, OR
#  2                  Sunrise Water Authority  Happy Valley, OR
#  3        Clackamas River Water - Clackamas     Clackamas, OR
#  4              Lake Oswego Municipal Water   Lake Oswego, OR
#  5                              Oregon City   Oregon City, OR
#  6                 Oak Lodge Water District     Milwaukie, OR
#  7                        City of West Linn     West Linn, OR
#  8                        City of Milwaukie     Milwaukie, OR
#  9                      City of Wilsonville   Wilsonville, OR
#
#                People served
#  0  Population served:87,700
#  1  Population served:65,000
#  2  Population served:46,228
#  3  Population served:41,338
#  4  Population served:36,453
#  5  Population served:33,940
#  6  Population served:30,000
#  7  Population served:25,002
#  8  Population served:20,500
#  9  Population served:22,729  ,
#                                 Utility name             City  \
#  0         Alder Creek Barlow Water District            Sandy
#  1                Ashdown Wood Water Company          Newberg
#  2                      Barlow Trail Estates         Portland
#  3                           Barlow, City of            Canby
#  4                      Big Foot Mobile Park            Sandy
#  5        Big Valley Woods Water Corporation           Boring
#  6              Boring Water District No. 24           Boring
#  7                    Brightwood Water Works       Brightwood
#  8                             Canby Regency         Portland
#  9                             Canby Utility            Canby
#  10                      Carver Mobile Ranch      Lake Oswego
#  11              Cedarhurst Improvement Club         Estacada
#  12                        City of Gladstone        Gladstone
#  13                        City of Milwaukie        Milwaukie
#  14                        City of West Linn        West Linn
#  15                      City of Wilsonville      Wilsonville
#  16        Clackamas River Water - Clackamas        Clackamas
#  17        Clackamas River Water - Clairmont        Clackamas
#  18                    Colton Water District           Colton
#  19              Country Club Water District       Brightwood
#  20            Currinsville Mobile Home Park            Sandy
#  21              Dietz Air Park Water System            Canby
#  22               Eagle Creek Mobile Estates      Eagle Creek
#  23             Eagle Crest Mobile Home Park      Eagle Creek
#  24                   Eastmont Water Company           Boring
#  25                  Estacada Mobile Village         Estacada
#  26                        Estacada, City of         Estacada
#  27                        Excalibur Village      Lake Oswego
#  28                 Forest Haven Subdivision          Molalla
#  29               Forest Park Mobile Village      Oregon City
#  30       Glenmorrie Cooperative Association      Lake Oswego
#  31                       Gnr Water District            Sandy
#  32             Government Camp Water System  Government Camp
#  33       Hiland Water Company - Shadow Wood          Newberg
#  34                  Kelso Water Association           Boring
#  35            Kingswood Heights Water Co-op      Lake Oswego
#  36                Lake Grove Water District      Lake Oswego
#  37              Lake Oswego Municipal Water      Lake Oswego
#  38                 Lark Meadows Association            Canby
#  39                         Molalla, City Of          Molalla
#  40                Mossy Brae Water District        West Linn
#  41           Mountain Air Water Association          Welches
#  42             Mountain View Mobile Estates         Estacada
#  43                    Mulino Water District           Mulino
#  44      North Brightwood Improv Association          Welches
#  45  North Clackamas County Water Commission      Oregon City
#  46                 Oak Lodge Water District        Milwaukie
#  47                              Oregon City      Oregon City
#  48              Orient Drive Mobile Estates           Boring
#  49           Paradise Community Association      Eagle Creek
#  50             Petes Mountain Water Company          Molalla
#  51                 Pioneer Mobile Home Park          Tangent
#  52         Polehn Heights Water Association      Oregon City
#  53     Ranchero Petite Improvement District           Boring
#  54           Rhododendron Water Association     Rhododendron
#  55               Riverbend Mobile Home Park        Clackamas
#  56            Riverbend-riverbank Community        West Linn
#  57                Rivergrove Water District      Lake Oswego
#  58                 Riverside Water District            Sandy
#  59                Riverview Mfgd Home Court          Tangent
#  60              Salmon Valley Water Company          Welches
#  61                           Sandy, City of            Sandy
#  62                   Skylands Water Company      Lake Oswego
#  63              Skyview Acres Water Company            Sandy
#  64             Sleepy Hollow Water District            Sandy
#  65                   South Fork Water Board      Oregon City
#  66            Southwood Park Water District          Newberg
#  67               Spar Tree Mobile Home Park     Happy Valley
#  68                      Springwater Estates         Estacada
#  69                      Steeves Mobile City        Milwaukie
#  70                  Sunrise Water Authority     Happy Valley
#  71        Timberline Rim Water Company Inc.     Rhododendron
#  72           Totem Village Mobile Home Park         Portland
#  73                    Twin Island Community      Eagle Creek
#  74                  Walnut Mobile Home Park      Wilsonville
#  75                    Welches Water Company            Sandy
#  76            Wildwood Annex Water District          Welches
#  77                      Workman Air Park #3          Newberg
#  78                       Wunder Mobile Park          Molalla
#  79             Zig Zag Village Water System          Molalla
#  80                      Zig Zag Water Co-op          Welches
#
#                  People served
#  0      Population served: 310
#  1       Population served: 75
#  2      Population served: 180
#  3      Population served: 140
#  4       Population served: 60
#  5      Population served: 420
#  6    Population served: 2,500
#  7      Population served: 100
#  8      Population served: 300
#  9   Population served: 16,866
#  10     Population served: 110
#  11      Population served: 60
#  12  Population served: 12,000
#  13  Population served: 20,500
#  14  Population served: 25,002
#  15  Population served: 22,729
#  16  Population served: 41,338
#  17  Population served: 14,458
#  18   Population served: 1,500
#  19     Population served: 150
#  20      Population served: 90
#  21      Population served: 85
#  22      Population served: 35
#  23     Population served: 300
#  24     Population served: 250
#  25     Population served: 150
#  26   Population served: 3,155
#  27     Population served: 180
#  28     Population served: 165
#  29      Population served: 85
#  30     Population served: 250
#  31      Population served: 60
#  32     Population served: 200
#  33     Population served: 125
#  34     Population served: 300
#  35     Population served: 138
#  36   Population served: 3,100
#  37  Population served: 36,453
#  38      Population served: 80
#  39   Population served: 9,139
#  40     Population served: 100
#  41     Population served: 200
#  42      Population served: 95
#  43     Population served: 660
#  44      Population served: 50
#  45  Population served: 87,700
#  46  Population served: 30,000
#  47  Population served: 33,940
#  48      Population served: 75
#  49      Population served: 75
#  50     Population served: 250
#  51     Population served: 300
#  52     Population served: 150
#  53      Population served: 40
#  54     Population served: 980
#  55     Population served: 550
#  56     Population served: 225
#  57   Population served: 4,000
#  58     Population served: 200
#  59     Population served: 400
#  60   Population served: 1,500
#  61  Population served: 10,655
#  62     Population served: 250
#  63     Population served: 200
#  64     Population served: 135
#  65  Population served: 65,000
#  66     Population served: 900
#  67      Population served: 25
#  68     Population served: 110
#  69      Population served: 80
#  70  Population served: 46,228
#  71     Population served: 800
#  72      Population served: 70
#  73      Population served: 80
#  74     Population served: 175
#  75     Population served: 100
#  76      Population served: 35
#  77      Population served: 75
#  78     Population served: 100
#  79      Population served: 80
#  80      Population served: 60  ]

# %%
table[0]
# Out:
#                               Utility name              City  \
# 0  North Clackamas County Water Commission   Oregon City, OR
# 1                   South Fork Water Board   Oregon City, OR
# 2                  Sunrise Water Authority  Happy Valley, OR
# 3        Clackamas River Water - Clackamas     Clackamas, OR
# 4              Lake Oswego Municipal Water   Lake Oswego, OR
# 5                              Oregon City   Oregon City, OR
# 6                 Oak Lodge Water District     Milwaukie, OR
# 7                        City of West Linn     West Linn, OR
# 8                        City of Milwaukie     Milwaukie, OR
# 9                      City of Wilsonville   Wilsonville, OR
#
#               People served
# 0  Population served:87,700
# 1  Population served:65,000
# 2  Population served:46,228
# 3  Population served:41,338
# 4  Population served:36,453
# 5  Population served:33,940
# 6  Population served:30,000
# 7  Population served:25,002
# 8  Population served:20,500
# 9  Population served:22,729

# %%
num_utilities = len(table[0])
num_utilities
# Out:
# 10

# %%
#Initialize an empty list to contain all of our data
contaminant_list = []
contaminants_column = []
for utility_vist in range(num_utilities):
    print(utility_vist)
    utility_vist = str(utility_vist+1)
    XPath = "/html/body/div[3]/main/figure[1]/table/tbody/tr["+utility_vist+"]/td[1]/a"
    selection = driver.find_element(By.XPATH, XPath).click()
    # Parse the resulting html with soup
    page_source = driver.page_source
    html_soup = soup(page_source, 'html.parser')
    
    #Get the name of the Water Utility
    Utility = html_soup.find('h1').text
    Utility
    
    #get the html data we need
    data_box = html_soup.find_all('div', class_='contaminant-name')
    
    for i in range(len(data_box)):
        data = data_box[i].find_all('span')
        data_measure = []
        d = {
            'Utility' : Utility,
            'Contaminant': '', 
            'Utility Measuremnt':'', 
            'EWG HEALTH GUIDELINE': '',
            'Legal Limit':'' 
        }
        
        contaminant_name = data_box[i].find('h3')
        d['Contaminant'] = contaminant_name
        
        for j in range(len(data)):
            measurement = data[j].text
            #print(measurement)
            data_measure.append(measurement)
            #print(data_measure)

        try:
            d['Utility Measuremnt'] = data_measure[data_measure.index('THIS UTILITY')+1]
        except ValueError:
            print("A value error arose")
        except:
            print("Something else went wrong")
        try:
            d['EWG HEALTH GUIDELINE'] = data_measure[data_measure.index('EWG HEALTH GUIDELINE')+1]
        except ValueError:
            print("A value error arose")
        except:
            print("Something else went wrong") 
        try:
            d['Legal Limit'] = data_measure[data_measure.index('LEGAL LIMIT')+1]
        except ValueError:
            print("A value error arose")
        except:
            print("Something else went wrong") 

        contaminant_list.append(d)
        

#     contaminants = []
#     for k in range(len(data_box)-1):
#         contaminant = data_box[k].find('h3').text
#         contaminants.append(contaminant)
        
#     contaminants_column.append(contaminants)
#         ### This where it is not connnecting it needs to index the right list
#     for c in contaminants:
#     contaminant_list[int(utility_vist)]['Contaminant'] = contaminant
#     print(Utility)
#     print(contaminants)
#     print(contaminant_list)
#     input('Press Enter')
    
    driver.back()
# Out:
# 0
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# 1
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# 2
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# 3
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# 4
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# 5
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# 6
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# 7
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# 8
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# 9
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose
# A value error arose

# %%
df = pd.DataFrame(contaminant_list)

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

df
# Out:
#                                      Utility  \
# 0    North Clackamas County Water Commission
# 1    North Clackamas County Water Commission
# 2    North Clackamas County Water Commission
# 3    North Clackamas County Water Commission
# 4    North Clackamas County Water Commission
# 5    North Clackamas County Water Commission
# 6    North Clackamas County Water Commission
# 7                     South Fork Water Board
# 8                     South Fork Water Board
# 9                     South Fork Water Board
# 10                    South Fork Water Board
# 11                    South Fork Water Board
# 12                    South Fork Water Board
# 13                    South Fork Water Board
# 14                   Sunrise Water Authority
# 15                   Sunrise Water Authority
# 16                   Sunrise Water Authority
# 17                   Sunrise Water Authority
# 18                   Sunrise Water Authority
# 19                   Sunrise Water Authority
# 20                   Sunrise Water Authority
# 21                   Sunrise Water Authority
# 22                   Sunrise Water Authority
# 23                   Sunrise Water Authority
# 24                   Sunrise Water Authority
# 25                   Sunrise Water Authority
# 26                   Sunrise Water Authority
# 27                   Sunrise Water Authority
# 28                   Sunrise Water Authority
# 29                   Sunrise Water Authority
# 30                   Sunrise Water Authority
# 31                   Sunrise Water Authority
# 32                   Sunrise Water Authority
# 33                   Sunrise Water Authority
# 34                   Sunrise Water Authority
# 35         Clackamas River Water - Clackamas
# 36         Clackamas River Water - Clackamas
# 37         Clackamas River Water - Clackamas
# 38         Clackamas River Water - Clackamas
# 39         Clackamas River Water - Clackamas
# 40         Clackamas River Water - Clackamas
# 41         Clackamas River Water - Clackamas
# 42         Clackamas River Water - Clackamas
# 43         Clackamas River Water - Clackamas
# 44         Clackamas River Water - Clackamas
# 45         Clackamas River Water - Clackamas
# 46         Clackamas River Water - Clackamas
# 47         Clackamas River Water - Clackamas
# 48         Clackamas River Water - Clackamas
# 49               Lake Oswego Municipal Water
# 50               Lake Oswego Municipal Water
# 51               Lake Oswego Municipal Water
# 52               Lake Oswego Municipal Water
# 53               Lake Oswego Municipal Water
# 54               Lake Oswego Municipal Water
# 55               Lake Oswego Municipal Water
# 56               Lake Oswego Municipal Water
# 57               Lake Oswego Municipal Water
# 58               Lake Oswego Municipal Water
# 59               Lake Oswego Municipal Water
# 60               Lake Oswego Municipal Water
# 61               Lake Oswego Municipal Water
# 62                               Oregon City
# 63                               Oregon City
# 64                               Oregon City
# 65                               Oregon City
# 66                               Oregon City
# 67                               Oregon City
# 68                               Oregon City
# 69                               Oregon City
# 70                               Oregon City
# 71                               Oregon City
# 72                               Oregon City
# 73                               Oregon City
# 74                               Oregon City
# 75                               Oregon City
# 76                  Oak Lodge Water District
# 77                  Oak Lodge Water District
# 78                  Oak Lodge Water District
# 79                  Oak Lodge Water District
# 80                  Oak Lodge Water District
# 81                  Oak Lodge Water District
# 82                  Oak Lodge Water District
# 83                  Oak Lodge Water District
# 84                  Oak Lodge Water District
# 85                  Oak Lodge Water District
# 86                  Oak Lodge Water District
# 87                  Oak Lodge Water District
# 88                  Oak Lodge Water District
# 89                  Oak Lodge Water District
# 90                         City of West Linn
# 91                         City of West Linn
# 92                         City of West Linn
# 93                         City of West Linn
# 94                         City of West Linn
# 95                         City of West Linn
# 96                         City of West Linn
# 97                         City of West Linn
# 98                         City of West Linn
# 99                         City of West Linn
# 100                        City of West Linn
# 101                        City of West Linn
# 102                        City of West Linn
# 103                        City of West Linn
# 104                        City of Milwaukie
# 105                        City of Milwaukie
# 106                        City of Milwaukie
# 107                        City of Milwaukie
# 108                        City of Milwaukie
# 109                        City of Milwaukie
# 110                        City of Milwaukie
# 111                        City of Milwaukie
# 112                        City of Milwaukie
# 113                        City of Milwaukie
# 114                        City of Milwaukie
# 115                        City of Milwaukie
# 116                        City of Milwaukie
# 117                        City of Milwaukie
# 118                      City of Wilsonville
# 119                      City of Wilsonville
# 120                      City of Wilsonville
# 121                      City of Wilsonville
# 122                      City of Wilsonville
# 123                      City of Wilsonville
# 124                      City of Wilsonville
# 125                      City of Wilsonville
# 126                      City of Wilsonville
# 127                      City of Wilsonville
# 128                      City of Wilsonville
# 129                      City of Wilsonville
# 130                      City of Wilsonville
# 131                      City of Wilsonville
#
#                           Contaminant Utility Measuremnt EWG HEALTH GUIDELINE  \
# 0          [Haloacetic acids (HAA5)†]           14.0 ppb              0.1 ppb
# 1    [Total trihalomethanes (TTHMs)†]           16.0 ppb             0.15 ppb
# 2                            [Barium]           1.77 ppb              700 ppb
# 3                           [Nitrate]          0.190 ppm             0.14 ppm
# 4               [Nitrate and nitrite]         0.0720 ppm             0.14 ppm
# 5                           [Nitrite]        0.00778 ppm
# 6                                None
# 7          [Haloacetic acids (HAA5)†]           21.6 ppb              0.1 ppb
# 8                           [Nitrate]          0.286 ppm             0.14 ppm
# 9    [Total trihalomethanes (TTHMs)†]           29.8 ppb             0.15 ppb
# 10                           [Barium]           2.89 ppb              700 ppb
# 11                         [Fluoride]         0.0286 ppm
# 12              [Nitrate and nitrite]          0.250 ppm             0.14 ppm
# 13                               None
# 14                          [Arsenic]          0.700 ppb            0.004 ppb
# 15            [Chromium (hexavalent)]          0.277 ppb             0.02 ppb
# 16         [Haloacetic acids (HAA5)†]           24.5 ppb              0.1 ppb
# 17         [Haloacetic acids (HAA9)†]           26.4 ppb             0.06 ppb
# 18                          [Nitrate]          0.606 ppm             0.14 ppm
# 19              [Nitrate and nitrite]          0.800 ppm             0.14 ppm
# 20   [Radium, combined (-226 & -228)]         0.24 pCi/L           0.05 pCi/L
# 21   [Total trihalomethanes (TTHMs)†]           33.8 ppb             0.15 ppb
# 22                           [Barium]           6.20 ppb              700 ppb
# 23               [Bromochloromethane]         0.0500 ppb
# 24                         [Chlorate]           66.2 ppb              210 ppb
# 25                 [Chromium (total)]          0.404 ppb
# 26                           [Cobalt]          0.123 ppb               70 ppb
# 27                         [Fluoride]          0.302 ppm
# 28                        [Germanium]         0.0935 ppb
# 29                        [Manganese]           48.7 ppb              100 ppb
# 30                       [Molybdenum]          0.440 ppb               40 ppb
# 31                          [Nitrite]        0.00234 ppm
# 32                        [Strontium]         0.0578 ppb            1,500 ppb
# 33                         [Vanadium]           4.05 ppb               21 ppb
# 34                               None
# 35            [Chromium (hexavalent)]         0.0843 ppb             0.02 ppb
# 36         [Haloacetic acids (HAA5)†]           26.0 ppb              0.1 ppb
# 37         [Haloacetic acids (HAA9)†]           28.5 ppb             0.06 ppb
# 38   [Total trihalomethanes (TTHMs)†]           33.8 ppb             0.15 ppb
# 39                           [Barium]           2.47 ppb              700 ppb
# 40                         [Chlorate]          101.4 ppb              210 ppb
# 41                         [Fluoride]         0.0267 ppm
# 42                        [Manganese]          0.313 ppb              100 ppb
# 43                          [Nitrate]          0.249 ppm             0.14 ppm
# 44              [Nitrate and nitrite]          0.181 ppm             0.14 ppm
# 45                          [Nitrite]         0.0134 ppm
# 46                        [Strontium]         0.0381 ppb            1,500 ppb
# 47                         [Vanadium]          0.910 ppb               21 ppb
# 48                               None
# 49            [Chromium (hexavalent)]         0.0925 ppb             0.02 ppb
# 50         [Haloacetic acids (HAA5)†]           12.7 ppb              0.1 ppb
# 51         [Haloacetic acids (HAA9)†]           6.79 ppb             0.06 ppb
# 52   [Total trihalomethanes (TTHMs)†]           18.2 ppb             0.15 ppb
# 53                           [Barium]           4.00 ppb              700 ppb
# 54                          [Bromate]          0.135 ppb              0.1 ppb
# 55                         [Chlorate]          123.3 ppb              210 ppb
# 56                 [Chromium (total)]         0.0326 ppb
# 57                        [Manganese]          0.990 ppb              100 ppb
# 58                          [Nitrate]         0.0733 ppm             0.14 ppm
# 59                        [Strontium]         0.0333 ppb            1,500 ppb
# 60                         [Vanadium]          0.560 ppb               21 ppb
# 61                               None
# 62            [Chromium (hexavalent)]          0.147 ppb             0.02 ppb
# 63         [Haloacetic acids (HAA5)†]           36.8 ppb              0.1 ppb
# 64         [Haloacetic acids (HAA9)†]           38.6 ppb             0.06 ppb
# 65                         [Nitrate*]          0.286 ppm             0.14 ppm
# 66   [Total trihalomethanes (TTHMs)†]           40.6 ppb             0.15 ppb
# 67                          [Barium*]           2.89 ppb              700 ppb
# 68                         [Chlorate]           56.6 ppb              210 ppb
# 69                 [Chromium (total)]          0.168 ppb
# 70                        [Fluoride*]         0.0286 ppm
# 71                        [Manganese]           1.05 ppb              100 ppb
# 72             [Nitrate and nitrite*]          0.250 ppm             0.14 ppm
# 73                        [Strontium]         0.0413 ppb            1,500 ppb
# 74                         [Vanadium]           1.20 ppb               21 ppb
# 75                               None
# 76            [Chromium (hexavalent)]         0.0833 ppb             0.02 ppb
# 77         [Haloacetic acids (HAA5)†]           27.6 ppb              0.1 ppb
# 78         [Haloacetic acids (HAA9)†]           38.2 ppb             0.06 ppb
# 79   [Total trihalomethanes (TTHMs)†]           35.3 ppb             0.15 ppb
# 80                          [Barium*]           1.77 ppb              700 ppb
# 81                         [Chlorate]           44.0 ppb              210 ppb
# 82                 [Chromium (total)]          0.165 ppb
# 83                        [Manganese]          0.368 ppb              100 ppb
# 84                         [Nitrate*]          0.190 ppm             0.14 ppm
# 85             [Nitrate and nitrite*]         0.0720 ppm             0.14 ppm
# 86                         [Nitrite*]        0.00778 ppm
# 87                        [Strontium]         0.0385 ppb            1,500 ppb
# 88                         [Vanadium]           1.24 ppb               21 ppb
# 89                               None
# 90            [Chromium (hexavalent)]          0.142 ppb             0.02 ppb
# 91         [Haloacetic acids (HAA5)†]           33.4 ppb              0.1 ppb
# 92         [Haloacetic acids (HAA9)†]           39.9 ppb             0.06 ppb
# 93                         [Nitrate*]          0.286 ppm             0.14 ppm
# 94   [Total trihalomethanes (TTHMs)†]           35.3 ppb             0.15 ppb
# 95                          [Barium*]           2.89 ppb              700 ppb
# 96                         [Chlorate]           53.5 ppb              210 ppb
# 97                 [Chromium (total)]          0.165 ppb
# 98                        [Fluoride*]         0.0286 ppm
# 99                        [Manganese]          0.472 ppb              100 ppb
# 100            [Nitrate and nitrite*]          0.250 ppm             0.14 ppm
# 101                       [Strontium]         0.0379 ppb            1,500 ppb
# 102                        [Vanadium]           1.23 ppb               21 ppb
# 103                              None
# 104           [Chromium (hexavalent)]           1.09 ppb             0.02 ppb
# 105        [Haloacetic acids (HAA5)†]          0.233 ppb              0.1 ppb
# 106        [Haloacetic acids (HAA9)†]           2.73 ppb             0.06 ppb
# 107                         [Nitrate]           2.20 ppm             0.14 ppm
# 108             [Nitrate and nitrite]           2.00 ppm             0.14 ppm
# 109  [Total trihalomethanes (TTHMs)†]           5.03 ppb             0.15 ppb
# 110                     [1,4-Dioxane]         0.0351 ppb             0.35 ppb
# 111                          [Barium]           3.94 ppb              700 ppb
# 112                [Chromium (total)]          0.827 ppb
# 113                        [Fluoride]         0.0438 ppm
# 114                       [Manganese]          0.867 ppb              100 ppb
# 115                       [Strontium]         0.0931 ppb            1,500 ppb
# 116                        [Vanadium]           9.38 ppb               21 ppb
# 117                              None
# 118                         [Bromate]           1.29 ppb              0.1 ppb
# 119           [Chromium (hexavalent)]         0.0580 ppb             0.02 ppb
# 120        [Haloacetic acids (HAA5)†]           5.02 ppb              0.1 ppb
# 121        [Haloacetic acids (HAA9)†]           8.21 ppb             0.06 ppb
# 122                         [Nitrate]          0.499 ppm             0.14 ppm
# 123             [Nitrate and nitrite]          0.499 ppm             0.14 ppm
# 124  [Total trihalomethanes (TTHMs)†]           13.0 ppb             0.15 ppb
# 125                          [Barium]           5.50 ppb              700 ppb
# 126                        [Chlorate]           92.3 ppb              210 ppb
# 127                [Chromium (total)]        0.00588 ppb
# 128                       [Manganese]           3.12 ppb              100 ppb
# 129                       [Strontium]         0.0380 ppb            1,500 ppb
# 130                        [Vanadium]           1.59 ppb               21 ppb
# 131                              None
#
#     Legal Limit
# 0        60 ppb
# 1        80 ppb
# 2     2,000 ppb
# 3        10 ppm
# 4        10 ppm
# 5         1 ppm
# 6
# 7        60 ppb
# 8        10 ppm
# 9        80 ppb
# 10    2,000 ppb
# 11        4 ppm
# 12       10 ppm
# 13
# 14       10 ppb
# 15
# 16       60 ppb
# 17
# 18       10 ppm
# 19       10 ppm
# 20      5 pCi/L
# 21       80 ppb
# 22    2,000 ppb
# 23
# 24
# 25      100 ppb
# 26
# 27        4 ppm
# 28
# 29
# 30
# 31        1 ppm
# 32
# 33
# 34
# 35
# 36       60 ppb
# 37
# 38       80 ppb
# 39    2,000 ppb
# 40
# 41        4 ppm
# 42
# 43       10 ppm
# 44       10 ppm
# 45        1 ppm
# 46
# 47
# 48
# 49
# 50       60 ppb
# 51
# 52       80 ppb
# 53    2,000 ppb
# 54       10 ppb
# 55
# 56      100 ppb
# 57
# 58       10 ppm
# 59
# 60
# 61
# 62
# 63       60 ppb
# 64
# 65       10 ppm
# 66       80 ppb
# 67    2,000 ppb
# 68
# 69      100 ppb
# 70        4 ppm
# 71
# 72       10 ppm
# 73
# 74
# 75
# 76
# 77       60 ppb
# 78
# 79       80 ppb
# 80    2,000 ppb
# 81
# 82      100 ppb
# 83
# 84       10 ppm
# 85       10 ppm
# 86        1 ppm
# 87
# 88
# 89
# 90
# 91       60 ppb
# 92
# 93       10 ppm
# 94       80 ppb
# 95    2,000 ppb
# 96
# 97      100 ppb
# 98        4 ppm
# 99
# 100      10 ppm
# 101
# 102
# 103
# 104
# 105      60 ppb
# 106
# 107      10 ppm
# 108      10 ppm
# 109      80 ppb
# 110
# 111   2,000 ppb
# 112     100 ppb
# 113       4 ppm
# 114
# 115
# 116
# 117
# 118      10 ppb
# 119
# 120      60 ppb
# 121
# 122      10 ppm
# 123      10 ppm
# 124      80 ppb
# 125   2,000 ppb
# 126
# 127     100 ppb
# 128
# 129
# 130
# 131

# %%
driver.quit()

# %%
df.to_csv('Resources/Data/97045_scrape.csv')
