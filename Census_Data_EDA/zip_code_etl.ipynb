# %%
# Import Dependencies
import pandas as pd
import os

# %%
#import zipcode dataset from https://simplemaps.com/data/us-zips
zip_code_csv = os.path.join("..","Resources","Data","uszips.csv")
zips_df = pd.read_csv(zip_code_csv)
zips_df
# Out:
#          zip       lat        lng         city state_id   state_name  zcta  \
# 0        601  18.18027  -66.75266     Adjuntas       PR  Puerto Rico  True
# 1        602  18.36075  -67.17541       Aguada       PR  Puerto Rico  True
# 2        603  18.45744  -67.12225    Aguadilla       PR  Puerto Rico  True
# 3        606  18.16585  -66.93716      Maricao       PR  Puerto Rico  True
# 4        610  18.29110  -67.12243       Anasco       PR  Puerto Rico  True
# ...      ...       ...        ...          ...      ...          ...   ...
# 33783  99923  55.98043 -130.03803        Hyder       AK       Alaska  True
# 33784  99925  55.55398 -132.96276      Klawock       AK       Alaska  True
# 33785  99926  55.12617 -131.48928   Metlakatla       AK       Alaska  True
# 33786  99927  56.33305 -133.60044  Point Baker       AK       Alaska  True
# 33787  99929  56.36089 -132.00635     Wrangell       AK       Alaska  True
#
# ...

# %%
oregon_zips = zips_df.loc[(zips_df['state_name']=="Oregon")]
oregon_zips
# Out:
#          zip       lat        lng         city state_id state_name  zcta  \
# 32511  97001  44.93328 -120.64169     Antelope       OR     Oregon  True
# 32512  97002  45.23774 -122.80030       Aurora       OR     Oregon  True
# 32513  97003  45.50372 -122.86482    Beaverton       OR     Oregon  True
# 32514  97004  45.25068 -122.45399  Beavercreek       OR     Oregon  True
# 32515  97005  45.49144 -122.80397    Beaverton       OR     Oregon  True
# ...      ...       ...        ...          ...      ...        ...   ...
# 32933  97913  43.64688 -117.28131        Nyssa       OR     Oregon  True
# 32934  97914  44.11085 -117.07383      Ontario       OR     Oregon  True
# 32935  97917  43.54150 -118.11651    Riverside       OR     Oregon  True
# 32936  97918  43.96255 -117.38073         Vale       OR     Oregon  True
# 32937  97920  44.06595 -117.75997     Westfall       OR     Oregon  True
#
#        parent_zcta  population  density  county_fips county_name  \
# ...

# %%
oregon_zips["county_name"].value_counts()
# Out:
# Lane          35
# Multnomah     33
# Marion        26
# Douglas       26
# Clackamas     24
# Washington    23
# Linn          17
# Klamath       17
# Lincoln       16
# Jackson       15
# Malheur       13
# Tillamook     13
# Umatilla      13
# Yamhill       11
# Grant         11
# Baker         10
# Josephine     10
# Deschutes      9
# Harney         9
# Lake           8
# Wasco          8
# Columbia       8
# Coos           8
# Clatsop        7
# Union          7
# Curry          6
# Benton         6
# Polk           6
# Sherman        5
# Morrow         5
# Wallowa        5
# Jefferson      4
# Crook          4
# Wheeler        3
# Hood River     3
# Gilliam        2
# Modoc          1
# Name: county_name, dtype: int64

# %%
oregon_zips = oregon_zips.drop(oregon_zips.county_name=="Modoc")
oregon_zips["county_name"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/1f/15wzh36x4xg7k54678mpffyc0000gn/T/ipykernel_32107/4159750712.py in <module>
# ----> 1 oregon_zips = oregon_zips.drop(oregon_zips.county_name=="Modoc")
#       2 oregon_zips["county_name"].value_counts()
#
# /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# ...
