# %%
# Import Dependencies
import pandas as pd
import os

# %%
#import zipcode dataset from https://simplemaps.com/data/us-zips
zip_code_csv = os.path.join("..","Resources","Data","uszips.csv")
zips_df = pd.read_csv(zip_code_csv,dtype={"zip": str,"county_fips":str})
zips_df
# Out:
#          zip       lat        lng         city state_id   state_name  zcta  \
# 0      00601  18.18027  -66.75266     Adjuntas       PR  Puerto Rico  True
# 1      00602  18.36075  -67.17541       Aguada       PR  Puerto Rico  True
# 2      00603  18.45744  -67.12225    Aguadilla       PR  Puerto Rico  True
# 3      00606  18.16585  -66.93716      Maricao       PR  Puerto Rico  True
# 4      00610  18.29110  -67.12243       Anasco       PR  Puerto Rico  True
# ...      ...       ...        ...          ...      ...          ...   ...
# 33783  99923  55.98043 -130.03803        Hyder       AK       Alaska  True
# 33784  99925  55.55398 -132.96276      Klawock       AK       Alaska  True
# 33785  99926  55.12617 -131.48928   Metlakatla       AK       Alaska  True
# 33786  99927  56.33305 -133.60044  Point Baker       AK       Alaska  True
# 33787  99929  56.36089 -132.00635     Wrangell       AK       Alaska  True
#
# ...

# %%
zips_df.dtypes
# Out:
# zip                  object
# lat                 float64
# lng                 float64
# city                 object
# state_id             object
# state_name           object
# zcta                   bool
# parent_zcta         float64
# population          float64
# density             float64
# county_fips          object
# county_name          object
# county_weights       object
# county_names_all     object
# county_fips_all      object
# imprecise              bool
# military               bool
# timezone             object
# dtype: object

# %%
zips_df['county_fips'].value_counts()
# Out:
# 06037    295
# 17031    167
# 04013    134
# 48201    132
# 06073    115
#         ...
# 13005      1
# 13183      1
# 13237      1
# 13023      1
# 72001      1
# Name: county_fips, Length: 3211, dtype: int64

# %%
zips_to_counties = zips_df[["zip","county_fips","state_id"]]

# %%
zips_to_counties.head()
# Out:
#      zip county_fips state_id
# 0  00601       72001       PR
# 1  00602       72003       PR
# 2  00603       72005       PR
# 3  00606       72093       PR
# 4  00610       72011       PR

# %%
zips_to_counties.to_csv('zips_to_counties.csv',index=False)

# %%
zips_to_counties.shape
# Out:
# (33788, 3)
